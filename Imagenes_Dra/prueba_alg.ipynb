# %% [markdown]
# # Prueba de los algoritmos para ver el speckel

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
ref1 = cv2.imread('ref_0002.tif', cv2.IMREAD_GRAYSCALE)
ref2 = cv2.imread('ref_0004.tif', cv2.IMREAD_GRAYSCALE)
son1 = cv2.imread('sonido_0002.tif', cv2.IMREAD_GRAYSCALE)
son2 = cv2.imread('sonido_0006.tif', cv2.IMREAD_GRAYSCALE)
# Out:
# [ WARN:0@746.937] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50495 (0xc53f) encountered
# [ WARN:0@746.952] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50495 (0xc53f) encountered
# [ WARN:0@746.960] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50495 (0xc53f) encountered
# [ WARN:0@746.973] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 50495 (0xc53f) encountered

# %%
# 1. Activamos la recarga automática (¡salvavidas en Jupyter!)
# %load_ext autoreload
# %autoreload 2

import sys
import os

# 2. Le decimos a Python que mire "una carpeta hacia atrás" (..) y entre a PCO_PixelFly
ruta_pco = os.path.abspath('../PCO_PixelFly')

if ruta_pco not in sys.path:
    sys.path.append(ruta_pco)

# 3. ¡Ahora ya puedes importar tus archivos!
# (Autocompleta los nombres correctos de tus archivos .py)
from procesamiento import filtros_en_frecuencia 
from procesamiento import operaciones_basicas

# --- Ejemplo de uso ---
# filtros_en_frecuencia.nombre_de_tu_funcion()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img_float = np.float64(ref1)

# Resta



# Pasa bajas
img_filtrada = filtros_en_frecuencia.filtro_pasa_bajas_frecuencia(img_float, radio_corte=50)

# 4. Visualizamos el antes y el después
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(ref1, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("Filtrada (Pasa Bajas)")
plt.imshow(img_filtrada, cmap='gray')
plt.show()
